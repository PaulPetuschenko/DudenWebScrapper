# %%
import requests
import bs4
import time
import logging, sys 
import json

logging.basicConfig(stream=sys.stderr, level=logging.DEBUG)

meanings = []
frequencies = []
words = []
wordart = []
grammar = []
Duden = {}

link = ['https://www.duden.de/rechtschreibung/d_Korrekturzeichen_fuer_tilgen']

def getLinkElement(res):
    soup = bs4.BeautifulSoup(res,"lxml")
    hookup = soup.find_all("nav", class_="hookup__group")
    return bs4.BeautifulSoup(str(hookup[1]), "lxml").select(".hookup__link")[1]
 
def getLink(link):
    a =  bs4.BeautifulSoup(str(link)).find_all('a')
    return "https://www.duden.de/" + str(a[0].get('href'))    

def writeWord(res):
    try:
        soup = bs4.BeautifulSoup(res,"lxml")
        word = soup.find("span", class_="lemma__main")
        return word.contents[0]
    
    except: 
        return ""

def extractTextFromLink(a):
    try:
        return a.contents[0]
    except:
        return a

def extractMeaning(word):
    out = word.contents[2].contents[0]

    try:
        out += word.contents[2].contents[1].contents[0]
    except: 
        pass

    try:
        out += word.contents[2].contents[2]
    except:
        pass

    return out

def extractTextFromManyInputs(lis):
    out = []
    for el in range(len(lis)):
        full_str = ""
        for elm in range(len(lis[el].contents)):
            full_str += str(extractTextFromLink(lis[el].contents[elm]))
        out.append(full_str)
    return out        

def writeMeaning(res):
    soup = bs4.BeautifulSoup(res,"lxml")
    
    if soup.find("div", id="bedeutung") != None:
        word = soup.find("div", id="bedeutung")
        return extractMeaning(word)
    
    elif soup.find("div", id="bedeutungen") != None:
        word = soup.find_all("div", class_="enumeration__text")
        return extractTextFromManyInputs(word)
    
    else:
        return ""
    pass

def writeGrammar(res):
    
    pass

def writeFrequency(res):
    try:
        soup = bs4.BeautifulSoup(res,"lxml")
        word = soup.find("span", class_="shaft__full")
        return word.contents[0]
    except: 
        return ""

def writeArticle(res):
    try:
        soup = bs4.BeautifulSoup(res,"lxml")
        word = soup.find("dd", class_="tuple__val")
        return word.contents[0]
    except:
        return ""
        
def parseDuden():
    parsedHTML = requests.get(link[0]).text

    Duden.update({writeWord(parsedHTML).replace("\xad", ""):[len(writeFrequency(parsedHTML)), writeArticle(parsedHTML), writeMeaning(parsedHTML), link[0]]})
    
    link[0] = getLink(getLinkElement(parsedHTML))
    pass


for a in range(0, 1000):
    time.sleep(0)
    parseDuden()

time.sleep(0)

with open('Duden.json', 'w') as f:
    json.dump(Duden, f)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/d_Korrekturzeichen_fuer_tilgen HTTP/1.1" 200 19555
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/a__anno HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/a__anno HTTP/1.1" 301 252
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/a__anno HTTP/1.1" 200 19639
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/a_a_Moll_Ar HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/a_a_Moll_Ar HTTP/1.1" 301 256
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/a_a_Moll_Ar HTTP/1.1" 200 19720
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/A_Abkuerzung HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/A_Abkuerzung HTTP/1.1" 301 257
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/A_Abkuerzung HTTP/1.1" 200 19703
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/ae_Buchstabe HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/ae_Buchstabe HTTP/1.1" 301 257
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/ae_Buchstabe HTTP/1.1" 200 20337
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/a_franzoesische_Praeposition HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/a_franzoesische_Praeposition HTTP/1.1" 301 273
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung
TTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abartigkeit HTTP/1.1" 301 256
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abartigkeit HTTP/1.1" 200 20327
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/a_bas HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/a_bas HTTP/1.1" 301 250
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/a_bas HTTP/1.1" 200 20299
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/abaesen HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/abaesen HTTP/1.1" 301 252
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/abaesen HTTP/1.1" 200 20451
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/abasten HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/abasten HTTP/1.1" 301 252
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/abasten HTTP/1.1" 200 20917
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abata HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abata HTTP/1.1" 301 250
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abata HTTP/1.1" 200 20078
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abate_Weltgeistlicher HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abate_Weltgeistlicher HTTP/1.1" 301 266
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abate_Weltgeistlicher HTTP/1.1" 200 20483
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abatis HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abatis HTTP/1.1" 301 251
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abatis HTTP/1.1" 200 20279
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abatjour HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abatjour HTTP/1.1" 301 253
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abatjour HTTP/1.1" 200 20435
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abaton HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abaton HTTP/1.1" 301 251
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abaton HTTP/1.1" 200 20595
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abattant HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abattant HTTP/1.1" 301 253
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abattant HTTP/1.1" 200 20396
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/a_battuta HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/a_battuta HTTP/1.1" 301 254
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/a_battuta HTTP/1.1" 200 20254
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abaetzung HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abaetzung HTTP/1.1" 301 254
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abaetzung HTTP/1.1" 200 20163
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abba HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abba HTTP/1.1" 301 249
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abba HTTP/1.1" 200 20302
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/abbaden HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/abbaden HTTP/1.1" 301 252
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/abbaden HTTP/1.1" 200 20187
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abbaggerung HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abbaggerung HTTP/1.1" 301 256
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abbaggerung HTTP/1.1" 200 20155
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/abbalgen HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/abbalgen HTTP/1.1" 301 253
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/abbalgen HTTP/1.1" 200 20321
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/abbalzen HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/abbalzen HTTP/1.1" 301 253
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/abbalzen HTTP/1.1" 200 20173
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abbaside HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abbaside HTTP/1.1" 301 253
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abbaside HTTP/1.1" 200 20425
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abbate HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abbate HTTP/1.1" 301 251
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abbate HTTP/1.1" 200 19442
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abbauarbeit HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abbauarbeit HTTP/1.1" 301 256
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abbauarbeit HTTP/1.1" 200 20222
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abbaubarkeit HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abbaubarkeit HTTP/1.1" 301 257
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abbaubarkeit HTTP/1.1" 200 20221
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abbauerscheinung HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abbauerscheinung HTTP/1.1" 301 261
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abbauerscheinung HTTP/1.1" 200 20258
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abbaugebiet HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abbaugebiet HTTP/1.1" 301 256
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abbaugebiet HTTP/1.1" 200 20168
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abbauhammer HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abbauhammer HTTP/1.1" 301 256
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abbauhammer HTTP/1.1" 200 20102
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abbaumethode HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abbaumethode HTTP/1.1" 301 257
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abbaumethode HTTP/1.1" 200 20187
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abbauplan HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abbauplan HTTP/1.1" 301 254
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abbauplan HTTP/1.1" 200 20232
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abbauprozess HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abbauprozess HTTP/1.1" 301 257
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abbauprozess HTTP/1.1" 200 20246
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abbaustelle HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abbaustelle HTTP/1.1" 301 256
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abbaustelle HTTP/1.1" 200 20264
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abbauverfahren HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abbauverfahren HTTP/1.1" 301 259
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abbauverfahren HTTP/1.1" 200 20225
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/abbauwuerdig HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/abbauwuerdig HTTP/1.1" 301 257
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/abbauwuerdig HTTP/1.1" 200 20214
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abbe_Weltgeistlicher HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abbe_Weltgeistlicher HTTP/1.1" 301 265
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abbe_Weltgeistlicher HTTP/1.1" 200 20578
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abbedingung HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abbedingung HTTP/1.1" 301 256
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abbedingung HTTP/1.1" 200 20166
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/abbegehren HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/abbegehren HTTP/1.1" 301 255
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/abbegehren HTTP/1.1" 200 20178
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/abbeiszen HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/abbeiszen HTTP/1.1" 301 254
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/abbeiszen HTTP/1.1" 200 21129
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abbeizmittel HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abbeizmittel HTTP/1.1" 301 257
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abbeizmittel HTTP/1.1" 200 20326
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/abberufen HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/abberufen HTTP/1.1" 301 254
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/abberufen HTTP/1.1" 200 20585
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abberufung HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abberufung HTTP/1.1" 301 255
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abberufung HTTP/1.1" 200 20483
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abbestellung HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abbestellung HTTP/1.1" 301 257
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abbestellung HTTP/1.1" 200 20344
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# ...
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abruestungsbemuehung HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abruestungsbemuehung HTTP/1.1" 301 265
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abruestungsbemuehung HTTP/1.1" 200 20301
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abruestungsexperte HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abruestungsexperte HTTP/1.1" 301 263
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abruestungsexperte HTTP/1.1" 200 20194
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/abruestungsfaehig HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/abruestungsfaehig HTTP/1.1" 301 262
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/abruestungsfaehig HTTP/1.1" 200 20171
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abruestungsfrage HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abruestungsfrage HTTP/1.1" 301 261
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abruestungsfrage HTTP/1.1" 200 20302
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abruestungskonferenz HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abruestungskonferenz HTTP/1.1" 301 265
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abruestungskonferenz HTTP/1.1" 200 20484
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abruestungsmasznahme HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abruestungsmasznahme HTTP/1.1" 301 265
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abruestungsmasznahme HTTP/1.1" 200 20206
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abruestungsprozess HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abruestungsprozess HTTP/1.1" 301 263
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abruestungsprozess HTTP/1.1" 200 20247
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abruestungsvereinbarung HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abruestungsvereinbarung HTTP/1.1" 301 268
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abruestungsvereinbarung HTTP/1.1" 200 20311
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abruestungsverpflichtung HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abruestungsverpflichtung HTTP/1.1" 301 269
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abruestungsverpflichtung HTTP/1.1" 200 20278
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/abrutschen HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/abrutschen HTTP/1.1" 301 255
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/abrutschen HTTP/1.1" 200 22432
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Abruzzische_Apennin HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Abruzzische_Apennin HTTP/1.1" 301 264
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Abruzzische_Apennin HTTP/1.1" 200 20287
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/ABS HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/ABS HTTP/1.1" 301 248
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/ABS HTTP/1.1" 200 20241
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/absacken HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/absacken HTTP/1.1" 301 253
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/absacken HTTP/1.1" 200 22266
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Absacker HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Absacker HTTP/1.1" 301 253
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Absacker HTTP/1.1" 200 20573
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/absagen HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/absagen HTTP/1.1" 301 252
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/absagen HTTP/1.1" 200 22866
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/absahnen HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/absahnen HTTP/1.1" 301 253
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/absahnen HTTP/1.1" 200 21520
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Absahnerin HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Absahnerin HTTP/1.1" 301 255
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Absahnerin HTTP/1.1" 200 20207
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Absam HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Absam HTTP/1.1" 301 250
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Absam HTTP/1.1" 200 20229
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/absatteln HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/absatteln HTTP/1.1" 301 254
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/absatteln HTTP/1.1" 200 20245
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Absaettigung HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Absaettigung HTTP/1.1" 301 257
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Absaettigung HTTP/1.1" 200 20214
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Absatzchance HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Absatzchance HTTP/1.1" 301 257
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Absatzchance HTTP/1.1" 200 20435
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Absatzeinbusze HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Absatzeinbusze HTTP/1.1" 301 259
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Absatzeinbusze HTTP/1.1" 200 20289
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Absatzerfolg HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Absatzerfolg HTTP/1.1" 301 257
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Absatzerfolg HTTP/1.1" 200 20138
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Absatzferkel HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Absatzferkel HTTP/1.1" 301 257
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Absatzferkel HTTP/1.1" 200 20215
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Absatzflaute HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Absatzflaute HTTP/1.1" 301 257
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Absatzflaute HTTP/1.1" 200 20484
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Absatzfoerderung HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Absatzfoerderung HTTP/1.1" 301 261
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Absatzfoerderung HTTP/1.1" 200 20588
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Absatzforschung HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Absatzforschung HTTP/1.1" 301 260
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Absatzforschung HTTP/1.1" 200 20478
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.duden.de:443
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET //rechtschreibung/Absatzgebiet HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.duden.de:80
# DEBUG:urllib3.connectionpool:http://www.duden.de:80 "GET /rechtschreibung/Absatzgebiet HTTP/1.1" 301 257
# DEBUG:urllib3.connectionpool:https://www.duden.de:443 "GET /rechtschreibung/Absatzgebiet HTTP/1.1" 200 20365
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-5dfcba1d6be4> in <module>
#     115
#     116 with open('Duden.json', 'w') as f:
# --> 117     json.dump(Duden, f)
#     118
#     119
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# C:\ProgramData\Anaconda3\lib\json\encoder.py in _iterencode(o, _current_indent_level)
#     429             yield from _iterencode_list(o, _current_indent_level)
#     430         elif isinstance(o, dict):
# --> 431             yield from _iterencode_dict(o, _current_indent_level)
#     432         else:
#     433             if markers is not None:
#
# C:\ProgramData\Anaconda3\lib\json\encoder.py in _iterencode_dict(dct, _current_indent_level)
#     403                 else:
#     404                     chunks = _iterencode(value, _current_indent_level)
# --> 405                 yield from chunks
#     406         if newline_indent is not None:
#     407             _current_indent_level -= 1
#
# C:\ProgramData\Anaconda3\lib\json\encoder.py in _iterencode_list(lst, _current_indent_level)
#     323                 else:
#     324                     chunks = _iterencode(value, _current_indent_level)
# --> 325                 yield from chunks
#     326         if newline_indent is not None:
#     327             _current_indent_level -= 1
#
# C:\ProgramData\Anaconda3\lib\json\encoder.py in _iterencode(o, _current_indent_level)
#     436                     raise ValueError("Circular reference detected")
#     437                 markers[markerid] = o
# --> 438             o = _default(o)
#     439             yield from _iterencode(o, _current_indent_level)
#     440             if markers is not None:
#
# C:\ProgramData\Anaconda3\lib\json\encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type Tag is not JSON serializable
